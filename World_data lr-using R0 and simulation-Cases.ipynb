# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("77countries.xlsx")
#df=df[0:30]
#State=df.State.unique()
#df_last_date=df[df['date']=="2020-09-03"]

# %%
df
# Out:
#         continent        location  total_deaths        R0  total_cases  \
# 0   North America   United States        185744  2.465409      6114406
# 1   South America          Brazil        123780  2.000668      3997865
# 2            Asia           India         67376  1.731947      3853406
# 3   North America          Mexico         65816  1.800513       610957
# 4          Europe  United Kingdom         41514  2.042228       338676
# ..            ...             ...           ...       ...          ...
# 72         Europe         Albania           296  2.268620         9728
# 73         Africa          Zambia           292  1.908191        12415
# 74         Africa         Senegal           287  1.453346        13743
# 75         Africa           Ghana           276  2.037094        44658
# 76         Europe          Greece           273  3.141513        10757
#
#     new_cases  population  population_density  median_age  aged_65_older  \
# 0       38754   331002647              35.608        38.3         15.413
# 1       46934   212559409              25.040        33.5          8.552
# 2       83883  1380004385             450.419        28.2          5.989
# 3        4921   128932753              66.444        29.3          6.857
# 4        1508    67886004             272.898        40.8         18.517
# ..        ...         ...                 ...         ...            ...
# 72        122     2877800             104.871        38.0         13.188
# 73         34    18383956              22.995        17.7          2.480
# 74         75    16743930              82.328        18.7          3.008
# 75        198    31072945             126.719        21.1          3.385
# 76        233    10423056              83.479        45.3         20.396
#
#     aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           9.732       54225.446              1.2                151.089
# 1           5.060       14103.452              3.4                177.961
# 2           3.414        6426.674             21.2                282.280
# 3           4.321       17336.469              2.5                152.783
# 4          12.527       39753.244              0.2                122.137
# ..            ...             ...              ...                    ...
# 72          8.643       11803.431              1.1                304.195
# 73          1.542        3689.251             57.5                234.499
# 74          1.796        2470.580             38.0                241.219
# 75          1.948        4227.630             12.0                298.245
# 76         14.524       24574.382              1.5                175.695
#
#     diabetes_prevalence  female_smokers  male_smokers  \
# 0                 10.79            19.1          24.6
# 1                  8.11            10.1          17.9
# 2                 10.39             1.9          20.6
# 3                 13.06             6.9          21.4
# 4                  4.28            20.0          24.7
# ..                  ...             ...           ...
# 72                10.08             7.1          51.2
# 73                 3.94             3.1          24.7
# 74                 2.42             0.4          16.6
# 75                 4.97             0.3           7.7
# 76                 4.55            35.3          52.0
#
#     hospital_beds_per_thousand  life_expectancy
# 0                         2.77            78.86
# 1                         2.20            75.88
# 2                         0.53            69.66
# 3                         1.38            75.05
# 4                         2.54            81.32
# ..                         ...              ...
# 72                        2.89            78.57
# 73                        2.00            63.89
# 74                         NaN            67.94
# 75                        0.90            64.07
# 76                        4.21            82.24
#
# [77 rows x 19 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   continent                   77 non-null     object
#  1   location                    77 non-null     object
#  2   total_deaths                77 non-null     int64
#  3   R0                          77 non-null     float64
#  4   total_cases                 77 non-null     int64
#  5   new_cases                   77 non-null     int64
#  6   population                  77 non-null     int64
#  7   population_density          77 non-null     float64
#  8   median_age                  77 non-null     float64
#  9   aged_65_older               77 non-null     float64
#  10  aged_70_older               76 non-null     float64
#  11  gdp_per_capita              77 non-null     float64
#  12  extreme_poverty             58 non-null     float64
#  13  cardiovasc_death_rate       77 non-null     float64
#  14  diabetes_prevalence         77 non-null     float64
#  15  female_smokers              72 non-null     float64
#  16  male_smokers                70 non-null     float64
#  17  hospital_beds_per_thousand  75 non-null     float64
#  18  life_expectancy             77 non-null     float64
# dtypes: float64(13), int64(4), object(2)
# memory usage: 11.6+ KB
# None

# %%
#Filling missing values

# %%
l=df.columns
l
# Out:
# Index(['continent', 'location', 'total_deaths', 'R0', 'total_cases',
#        'new_cases', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'hospital_beds_per_thousand', 'life_expectancy'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         continent                location  total_deaths        R0  \
# 0   North America           United States        185744  2.465409
# 1   South America                  Brazil        123780  2.000668
# 2            Asia                   India         67376  1.731947
# 3   North America                  Mexico         65816  1.800513
# 4          Europe          United Kingdom         41514  2.042228
# 5          Europe                   Italy         35497  4.184995
# 8            Asia                    Iran         21797  1.532991
# 9   South America                Colombia         20348  1.991294
# 10         Europe                  Russia         17414  2.716937
# 11         Africa            South Africa         14389  1.761732
# 12  South America                   Chile         11344  2.250374
# 13         Europe                 Belgium          9898  3.598751
# 15  North America                  Canada          9135  2.764913
# 16  South America               Argentina          8971  2.114039
# 17           Asia               Indonesia          7616  2.023743
# 19  South America                 Ecuador          6619  1.872841
# 20           Asia                  Turkey          6462  1.711242
# 21           Asia                Pakistan          6328  1.362303
# 23         Europe                  Sweden          5820  3.206547
# 24         Africa                   Egypt          5461  1.434267
# 26           Asia                   China          4727  2.436220
# 27           Asia              Bangladesh          4351  1.618151
# 29         Europe                 Romania          3721  2.701301
# 32         Europe                 Ukraine          2656  3.038230
# 34  North America                  Panama          2030  1.823209
# 36           Asia              Kazakhstan          1889  2.260230
# 37         Europe                Portugal          1827  3.112976
# 38         Europe                 Ireland          1777  2.265882
# 39  North America      Dominican Republic          1765  1.846620
# 41         Africa                 Algeria          1525  1.359804
# 43         Africa                 Morocco          1216  1.656326
# 44           Asia              Kyrgyzstan          1059  1.737408
# 46           Asia                  Israel           969  2.094296
# 47           Asia                 Armenia           884  2.455895
# 48         Africa                Ethiopia           846  2.061205
# 49  North America             El Salvador           739  1.807100
# 50         Europe                 Austria           734  3.014221
# 54        Oceania               Australia           663  2.555908
# 55         Europe                Bulgaria           642  3.516514
# 56         Europe  Bosnia and Herzegovina           627  2.773516
# 57         Europe                 Denmark           626  3.178221
# 58         Europe                 Hungary           619  3.091244
# 59         Africa                   Kenya           577  1.662634
# 60           Asia                   Yemen           571  1.062837
# 63  North America              Costa Rica           453  1.959368
# 68  South America                Paraguay           358  1.888903
# 70           Asia             South Korea           329  2.660926
# 72         Europe                 Albania           296  2.268620
# 73         Africa                  Zambia           292  1.908191
# 75         Africa                   Ghana           276  2.037094
# 76         Europe                  Greece           273  3.141513
#
#     total_cases  new_cases  population  population_density  median_age  \
# 0       6114406      38754   331002647              35.608        38.3
# 1       3997865      46934   212559409              25.040        33.5
# 2       3853406      83883  1380004385             450.419        28.2
# 3        610957       4921   128932753              66.444        29.3
# 4        338676       1508    67886004             272.898        40.8
# 5        271515       1326    60461828             205.859        47.9
# 8        378752       1858    83992953              49.831        32.4
# 9        633339       9270    50882884              44.223        32.2
# 10      1005000       4952   145934460               8.823        39.6
# 11       630595       2336    59308690              46.754        27.3
# 12       414739       1594    19116209              24.282        35.4
# 13        85817          0    11589616             375.564        41.8
# 15       129923        498    37742157               4.037        41.4
# 16       428226      10504    45195777              16.177        31.9
# 17       180646       3075   273523621             145.725        29.3
# 19       115457       1148    17643060              66.939        28.1
# 20       273301       1596    84339067             104.914        31.6
# 21       297014        424   220892331             255.573        23.5
# 23        84532          0    10099270              24.718        41.0
# 24        99280        165   102334403              97.999        25.3
# 26        89953         19  1439323774             147.674        38.7
# 27       317528       2582   164689383            1265.036        27.5
# 29        89891       1298    19237682              85.129        43.0
# 32       125789       2486    43733759              77.390        41.4
# 34        94084        532     4314768              55.133        29.7
# 36       132354        659    18776707               6.681        30.6
# 37        58633        390    10196707             112.371        46.2
# 38        29114         89     4937796              69.874        38.7
# 39        95627        648    10847904             222.873        27.6
# 41        45158        325    43851043              17.348        29.1
# 43        65453       1672    36910558              80.080        29.6
# 44        44135         99     6524191              32.333        26.3
# 46       122539       3274     8655541             402.606        30.6
# 47        44075        197     2963234             102.931        35.7
# 48        54409       1105   114963583             104.957        19.8
# 49        25904          0     6486201             307.811        27.6
# 50        28183        442     9006400             106.749        44.4
# 54        25923        104    25499881               3.202        37.9
# 55        16454        188     6948445              65.180        44.7
# 56        20517        283     3280815              68.496        42.5
# 57        17195        111     5792203             136.520        42.3
# 58         6622        365     9660350             108.043        43.4
# 59        34493        178    53771300              87.324        20.0
# 60         1976         14    29825968              53.508        20.3
# 63        43305       1121     5094114              96.079        33.6
# 68        19138        800     7132530              17.144        26.5
# 70        20644        195    51269183             527.967        43.4
# 72         9728        122     2877800             104.871        38.0
# 73        12415         34    18383956              22.995        17.7
# 75        44658        198    31072945             126.719        21.1
# 76        10757        233    10423056              83.479        45.3
#
#     aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0          15.413          9.732       54225.446              1.2
# 1           8.552          5.060       14103.452              3.4
# 2           5.989          3.414        6426.674             21.2
# 3           6.857          4.321       17336.469              2.5
# 4          18.517         12.527       39753.244              0.2
# 5          23.021         16.240       35220.084              2.0
# 8           5.440          3.182       19082.620              0.2
# 9           7.646          4.312       13254.949              4.5
# 10         14.178          9.393       24765.954              0.1
# 11          5.344          3.053       12294.876             18.9
# 12         11.087          6.938       22767.037              1.3
# 13         18.571         12.849       42658.576              0.2
# 15         16.984         10.797       44017.591              0.5
# 16         11.198          7.441       18933.907              0.6
# 17          5.319          3.053       11188.744              5.7
# 19          7.104          4.458       10581.936              3.6
# 20          8.153          5.061       25129.341              0.2
# 21          4.495          2.780        5034.708              4.0
# 23         19.985         13.433       46949.283              0.5
# 24          5.159          2.891       10550.206              1.3
# 26         10.641          5.929       15308.712              0.7
# 27          5.098          3.262        3523.984             14.8
# 29         17.850         11.690       23313.199              5.7
# 32         16.462         11.133        7894.393              0.1
# 34          7.918          5.030       22267.037              2.2
# 36          6.991          4.625       24055.588              0.1
# 37         21.502         14.924       27936.896              0.5
# 38         13.928          8.678       67335.293              0.2
# 39          6.981          4.419       14600.861              1.6
# 41          6.211          3.857       13913.839              0.5
# 43          6.769          4.209        7485.013              1.0
# 44          4.489          2.882        3393.474              1.4
# 46         11.733          7.359       33132.320              0.5
# 47         11.232          7.571        8787.580              1.8
# 48          3.526          2.063        1729.927             26.7
# 49          8.273          5.417        7292.458              2.2
# 50         19.202         13.748       45436.686              0.7
# 54         15.504         10.129       44648.710              0.5
# 55         20.801         13.272       18563.307              1.5
# 56         16.569         10.711       11713.895              0.2
# 57         19.677         12.325       46682.515              0.2
# 58         18.577         11.976       26777.561              0.5
# 59          2.686          1.528        2993.028             36.8
# 60          2.922          1.583        1479.147             18.8
# 63          9.468          5.694       15524.995              1.3
# 68          6.378          3.833        8827.010              1.7
# 70         13.914          8.622       35938.374              0.2
# 72         13.188          8.643       11803.431              1.1
# 73          2.480          1.542        3689.251             57.5
# 75          3.385          1.948        4227.630             12.0
# 76         20.396         14.524       24574.382              1.5
#
#     cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                 151.089                10.79            19.1          24.6
# 1                 177.961                 8.11            10.1          17.9
# 2                 282.280                10.39             1.9          20.6
# 3                 152.783                13.06             6.9          21.4
# 4                 122.137                 4.28            20.0          24.7
# 5                 113.151                 4.78            19.8          27.8
# 8                 270.308                 9.59             0.8          21.1
# 9                 124.240                 7.44             4.7          13.5
# 10                431.297                 6.18            23.4          58.3
# 11                200.380                 5.52             8.1          33.2
# 12                127.993                 8.46            34.2          41.5
# 13                114.898                 4.29            25.1          31.4
# 15                105.599                 7.37            12.0          16.6
# 16                191.032                 5.50            16.2          27.7
# 17                342.864                 6.32             2.8          76.1
# 19                140.448                 5.55             2.0          12.3
# 20                171.285                12.13            14.1          41.1
# 21                423.031                 8.35             2.8          36.7
# 23                133.982                 4.79            18.8          18.9
# 24                525.432                17.31             0.2          50.1
# 26                261.899                 9.74             1.9          48.4
# 27                298.003                 8.38             1.0          44.7
# 29                370.946                 9.74            22.9          37.1
# 32                539.849                 7.11            13.5          47.4
# 34                128.346                 8.33             2.4           9.9
# 36                466.792                 7.11             7.0          43.1
# 37                127.842                 9.85            16.3          30.0
# 38                126.459                 3.28            23.0          25.7
# 39                266.653                 8.20             8.5          19.1
# 41                278.364                 6.73             0.7          30.4
# 43                419.146                 7.14             0.8          47.1
# 44                436.362                 7.11             3.6          50.5
# 46                 93.320                 6.74            15.4          35.4
# 47                341.010                 7.11             1.5          52.1
# 48                182.634                 7.47             0.4           8.5
# 49                167.295                 8.87             2.5          18.8
# 50                145.183                 6.35            28.4          30.9
# 54                107.791                 5.07            13.0          16.5
# 55                424.688                 5.81            30.1          44.4
# 56                329.635                10.08            30.2          47.7
# 57                114.767                 6.41            19.3          18.8
# 58                278.296                 7.55            26.8          34.8
# 59                218.637                 2.92             1.2          20.4
# 60                495.003                 5.35             7.6          29.2
# 63                137.973                 8.78             6.4          17.4
# 68                199.128                 8.27             5.0          21.6
# 70                 85.998                 6.80             6.2          40.9
# 72                304.195                10.08             7.1          51.2
# 73                234.499                 3.94             3.1          24.7
# 75                298.245                 4.97             0.3           7.7
# 76                175.695                 4.55            35.3          52.0
#
#     hospital_beds_per_thousand  life_expectancy
# 0                        2.770            78.86
# 1                        2.200            75.88
# 2                        0.530            69.66
# 3                        1.380            75.05
# 4                        2.540            81.32
# 5                        3.180            83.51
# 8                        1.500            76.68
# 9                        1.710            77.29
# 10                       8.050            72.58
# 11                       2.320            64.13
# 12                       2.110            80.18
# 13                       5.640            81.63
# 15                       2.500            82.43
# 16                       5.000            76.67
# 17                       1.040            71.72
# 19                       1.500            77.01
# 20                       2.810            77.69
# 21                       0.600            67.27
# 23                       2.220            82.80
# 24                       1.600            71.99
# 26                       4.340            76.91
# 27                       0.800            72.59
# 29                       6.892            76.05
# 32                       8.800            72.06
# 34                       2.300            78.51
# 36                       6.700            73.60
# 37                       3.390            82.05
# 38                       2.960            82.30
# 39                       1.600            74.08
# 41                       1.900            76.88
# 43                       1.100            76.68
# 44                       4.500            71.45
# 46                       2.990            82.97
# 47                       4.200            75.09
# 48                       0.300            66.60
# 49                       1.300            73.32
# 50                       7.370            81.54
# 54                       3.840            83.44
# 55                       7.454            75.05
# 56                       3.500            77.40
# 57                       2.500            80.90
# 58                       7.020            76.88
# 59                       1.400            66.70
# 60                       0.700            66.12
# 63                       1.130            80.28
# 68                       1.300            74.25
# 70                      12.270            83.03
# 72                       2.890            78.57
# 73                       2.000            63.89
# 75                       0.900            64.07
# 76                       4.210            82.24

# %%
df_numerical=df.iloc[:,2:]

# %%
df_numerical.shape
# Out:
# (51, 17)

# %% [markdown]
# ### Using only Elasticnet regression

# %%
df_numerical.drop(['new_cases'],axis=1,inplace=True)

# %%
y_train_reg = df_numerical['total_cases']
x_train_reg = df_numerical.drop('total_cases',axis=1)
x_test=x_train_reg.iloc[2:3,:]

# %%
from sklearn.linear_model import HuberRegressor
from sklearn import linear_model
ridge_reg = linear_model.Ridge(alpha=.5)
ridge_reg.fit(x_train_reg,y_train_reg)
# Out:
# Ridge(alpha=0.5)

# %%
ridge_reg.predict(x_test)
# Out:
# array([73006.9691871])

# %%
lm=LinearRegression()

# %%
lm.fit(x_train_reg,y_train_reg)
# Out:
# LinearRegression()

# %%
lm.predict(x_test)
# Out:
# array([73101.45170621])

# %%
coeff=en_reg.coef_

# %%
intercept=en_reg.intercept_

# %%
def dictionary(df,location):
    df_location=df[df['location']==location]
    df_location=df_location.iloc[:,3:]
    df_location_dict=df_location.to_dict('records')
    
    return df_location_dict

# %%
location="India"
df_location_dict=dictionary(df,location)

# %%
death=inter
k=0
for i in df_location_dict[0].values():
    death=death+(i*coeff[k])
    k=k+1

# %%
death
# Out:
# 71241.1945330599

# %%
from sklearn.linear_model import ElasticNet

# %%
lasso_reg = linear_model.Lasso(alpha=0.1)
lasso_reg.fit(x_train_reg,y_train_reg)

lasso_reg.predict(x_test)
# Out:
# array([2983815.35550532])

# %%
en_reg = ElasticNet(random_state=0)
en_reg.fit(x_train_reg,y_train_reg)

en_reg.predict(x_test)
# Out:
# array([3003231.25668595])

# %%
en_reg.coef_[0]
# Out:
# -26.200453728402575

# %%
en_reg.intercept_
# Out:
# -6924.314960388718

# %%
en_reg.n_features_in_
# Out:
# 16

# %%
x_train_reg.columns
# Out:
# Index(['total_deaths', 'R0', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'hospital_beds_per_thousand', 'life_expectancy'],
#       dtype='object')

# %%
x_train_reg.iloc[2:3,:]
# Out:
#    total_deaths        R0  population  population_density  median_age  \
# 2         67376  1.731947  1380004385             450.419        28.2
#
#    aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 2          5.989          3.414        6426.674             21.2
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 2                 282.28                10.39             1.9          20.6
#
#    hospital_beds_per_thousand  life_expectancy
# 2                        0.53            69.66

# %%
R0=1.731947
total_cases=3853406
new_cases=83883
population=1380004385
population_density=450.419
median_age=28.2
aged_65_older=5.989
aged_70_older=3.414
gdp_per_capita=6426.674
extreme_poverty=21.2
cardiovasc_death_rate=282.28
diabetes_prevalence=10.39
female_smokers=1.9
male_smokers=20.6
hospital_beds_per_thousand=0.53
life_expectancy=69.66

# %%
intercept=en_reg.intercept_
R0_coef=en_reg.coef_[0]
total_cases_coef=en_reg.coef_[1]
new_cases_coef=en_reg.coef_[2]
population_coef=en_reg.coef_[3]
population_density_coef=en_reg.coef_[4]
median_age_coef=en_reg.coef_[5]
aged_65_older_coef=en_reg.coef_[6]
aged_70_older_coef=en_reg.coef_[7]
gdp_per_capita_coef=en_reg.coef_[8]
extreme_poverty_coef=en_reg.coef_[9]
cardiovasc_death_rate_coef=en_reg.coef_[10]
diabetes_prevalence_coef=en_reg.coef_[11]
female_smokers_coef=en_reg.coef_[12]
male_smokers_coef=en_reg.coef_[13]
hospital_beds_per_thousand_coef=en_reg.coef_[14]
life_expectancy_coef=en_reg.coef_[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-056e3df383c3> in <module>
#      15 male_smokers_coef=en_reg.coef_[13]
#      16 hospital_beds_per_thousand_coef=en_reg.coef_[14]
# ---> 17 life_expectancy_coef=en_reg.coef_[15]
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
diabetes_prevalence_coef
hospital_beds_per_thousand_coef
median_age_coef
total_cases_coef
aged_70_older_coef
extreme_poverty_coef
female_smokers_coef
male_smokers_coef
R0_coef
# Out:
# 410.930002769215

# %%
median_age_coef
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b7a9d59edcda> in <module>
# ----> 1 median_age_coef
#
# NameError: name 'median_age_coef' is not defined

# %%
death=intercept+(R0_coef*R0)+(total_cases_coef*total_cases)+(new_cases_coef*new_cases)+(population_coef*population)+(population_density_coef*population_density)+(median_age_coef*median_age)+(aged_65_older_coef*aged_65_older)+(aged_70_older_coef*aged_70_older)+(gdp_per_capita_coef*gdp_per_capita)+(extreme_poverty_coef*extreme_poverty)+(cardiovasc_death_rate_coef*cardiovasc_death_rate)+(diabetes_prevalence_coef*diabetes_prevalence)+(female_smokers_coef*female_smokers)+(male_smokers_coef*male_smokers)+(hospital_beds_per_thousand_coef*hospital_beds_per_thousand)+(life_expectancy_coef*life_expectancy)

# %%
death
# Out:
# 72393.51183923168

# %%
en_reg.coef_
# Out:
# array([-2.62004537e+01,  3.60584668e-02, -8.06213173e-01, -2.18981243e-06,
#        -2.99663967e+00,  4.10930003e+02, -3.72163973e+02,  7.08752062e+02,
#        -7.54569970e-02, -1.72813896e+01, -1.30774630e+01,  3.76619160e+02,
#        -1.49054329e+02, -8.97911126e+01, -7.58936357e+02,  5.45567485e+01])
